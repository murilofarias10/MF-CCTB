# %% [markdown]
# Object Oriented Programming
#     Primitive types -> int, str, boolean, data types.
#         is called first other function
#             Objects
#
# Functional Promgramming
#     we can past a function as a parameter or an argument to another functional
#         is called higher order functinal
#             Functions
#
#
# our purporse to disccuss that diagram was
# 1. To make some analogy: How different tasks are handled by different roles or person.
# Similar approach is designed to andle various tasks in any computing device.
# Mobile, Laptop, Super Computer, Virtual Machine.
#
# Analogy: How certain steps of a paeticular taks or job are to be performed.
# Whether the taks are to be performed: Sequentially or In parallel.
#
# If we need to read data from multiple files:
# Then: it is good idea tor perform read operation in parallel because all there read operations are indepenent.
#
# Aftert making this decision that cedrtain tasks can be performed in Parallel: We have 2 choices:
# 1 We can use multiple threads to get the job done.
# 2 We can use differents process to get the job done.
#
# Who is taking care fo processing power in a computing: Processor, CPU/GPU and TPU
#
# Processing Chip -> Processor, Intel AMD
# Single Core Processor or Multi Core
# Datasheet or documentation
#
# Threads in our program -> Actuall workers -> Processing power -> Processor
#
# We need Thread Scheduling on a single processor.
# Because we cant have all threas running in parallel on a single core processor.
#
# If you are writing your multi-thread or multi processor code on a single core processor.
# You will not get much advantages.
#
# Cores are the physical processing units in a CPU.
#
# Threads are the tasks that can run on a CPU.
#
# Concurrency: Multiple tasks start, run, and complete in overlapping time periods. They don’t necessarily run at the same exact moment but are managed so they appear to run simultaneously.  does not require multiple CPU cores.
#
# Parallelism: Multiple tasks run at the exact same time on different CPU cores.
#     (For data engineer, ML solutions)
#
# One Approach:
# First,  Read all record from dtudent_marks.txt
# Then start calculating the average for each student and calculate all data in memory untill average is calculated for each record.
# Then write all data to the output file.
#
# Another Approach:
# Road one record at time,
# Calculate the average
# Write the avarega to the output
